# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/Deepak2gr/Summer-Olympic-medals-1976-to-2008/main/Summer-Olympic-medals-1976-to-2008.csv",encoding='latin-1')
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
# info about thr data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
#checking for null
df.isnull().sum().sum()
# Out:
# 1287

# %%
df.describe()
# Out:
#                Year
# count  15316.000000
# mean    1993.620789
# std       10.159851
# min     1976.000000
# 25%     1984.000000
# 50%     1996.000000
# 75%     2004.000000
# max     2008.000000

# %%
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (15316, 11)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['Count'] = 1
df['Count']
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal  Count
# 0  Silver      1
# 1  Bronze      1
# 2    Gold      1
# 3  Silver      1
# 4  Bronze      1

# %%
df["Gender"] = df["Gender"].astype("category")
df["Gender"]
df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal  Count
# 0  Silver      1
# 1  Bronze      1
# 2    Gold      1
# 3  Silver      1
# 4  Bronze      1

# %%
medal_color = ['Bronze', 'Silver', 'Gold']
medals = pd.api.types.CategoricalDtype(ordered=True, categories=medal_color)
df['Medal'] = df['Medal'].astype(medals)
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15428        GUENOT, Christophe    Men          FRA         France
# 15429       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15430          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15431            GUENOT, Steeve    Men          FRA         France
# 15432             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal  Count
# 0                W  Silver      1
# 1                M  Bronze      1
# 2                M    Gold      1
# 3                M  Silver      1
# 4                W  Bronze      1
# ...            ...     ...    ...
# 15428            M  Bronze      1
# 15429            M    Gold      1
# 15430            M  Silver      1
# 15431            M    Gold      1
# 15432            M    Gold      1
#
# [15316 rows x 12 columns]

# %%
# convert the marathon's year into object data type
df['Year'] = df['Year'].astype(str)
df['Year'] = df['Year'].str.extract('(\d{,4})')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\2105837569.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df['Year'] = df['Year'].str.extract('(\d{,4})')

# %%
year_order = ['1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008']
years = pd.api.types.CategoricalDtype(ordered=True, categories=year_order)
df['Year'] = df['Year'].astype(years)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15316 entries, 0 to 15432
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  category
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  category
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  category
#  11  Count         15316 non-null  int64
# dtypes: category(3), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
# contribution in olympics through time 
plt.figure(figsize=(10, 4))
df.groupby('Year')['Count'].size().plot.line(color='purple', linewidth=5.0)
plt.title('Overall Athletes contribution in olympics through time', fontsize=17, color='darkblue')
plt.xlabel('Years', fontweight='bold', color='darkblue')
plt.ylabel('No. of Athlete', fontweight='bold', color='darkblue')
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['1976', '1980', '1984', '1988', '1992', '1996', '2000', '2004', '2008']);
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\2336767522.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Year')['Count'].size().plot.line(color='purple', linewidth=5.0)

# %%
# plot Athletes contribution in olympics through time 
plt.figure(figsize=(10, 5))
sb.countplot(df['Year'], palette=sb.color_palette("Blues", 9))
plt.title('Overall Athletes contribution in olympics through the time ')
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\268148803.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(df['Year'], palette=sb.color_palette("Blues", 9))
# Text(0.5, 1.0, 'Overall Athletes contribution in olympics through the time ')

# %%
# disply counts of medals
df['Medal'].value_counts()
# Out:
# Medal
# Bronze    5258
# Gold      5042
# Silver    5016
# Name: count, dtype: int64

# %%
# plot awarded medals through years
plt.figure(figsize=(10, 5))
sb.countplot(data=df, x='Year', hue='Medal', palette=sb.color_palette("YlOrBr", 3))
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.title('Overall awarded Medals through years', fontsize=17, color='brown')
plt.xlabel('Years', fontweight='bold', color='brown')
plt.ylabel('No. of Medals', fontweight='bold', color='brown');

# %%
# clculate the counts of awrded medals for atheletes 
athlete_order = df['Athlete'].value_counts().head(10).index

# plot top 10 awarded Athletes
plt.figure(figsize=(9, 5))
sb.countplot(data=df, y='Athlete', order=athlete_order, palette=sb.color_palette('mako', 10))
plt.title('Top 10 Athletes with the most awarded Medals', fontsize=17, color='darkblue')
plt.xlabel('No. of awrded medals', fontweight='bold', color='darkblue')
plt.ylabel('Athlete Name', fontweight='bold', color='darkblue');
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\2156663888.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, y='Athlete', order=athlete_order, palette=sb.color_palette('mako', 10))

# %%
df['Country'].value_counts()
# Out:
# Country
# United States      1992
# Soviet Union       1021
# Australia           798
# Germany             691
# China               679
#                    ...
# Cote d'Ivoire         1
# Djibouti              1
# Senegal               1
# Virgin Islands*       1
# Afghanistan           1
# Name: count, Length: 127, dtype: int64

# %%
# plot countries of the top 10 rewarded medals
plt.figure(figsize=(15, 5))
highest_country = df['Country'].value_counts().head(10).index
sb.countplot(data=df, x='Country', order=highest_country, palette=sb.color_palette("mako", 10))
plt.title('Top 10 Countries with the most awarded Medals', fontsize=17, color='darkblue')
plt.xlabel('Country', fontweight='bold', color='darkblue')
plt.ylabel('No. of Medals', fontweight='bold', color='darkblue');
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\3280396927.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='Country', order=highest_country, palette=sb.color_palette("mako", 10))

# %%
df['Sport'].value_counts()
# Out:
# Sport
# Aquatics             2210
# Athletics            1523
# Rowing               1377
# Hockey                817
# Gymnastics            783
# Handball              780
# Volleyball            695
# Canoe / Kayak         672
# Football              669
# Basketball            646
# Fencing               606
# Wrestling             533
# Cycling               483
# Equestrian            423
# Sailing               417
# Boxing                416
# Judo                  396
# Shooting              345
# Baseball              335
# Weightlifting         311
# Softball              180
# Archery               162
# Table Tennis          120
# Badminton             120
# Tennis                118
# Modern Pentathlon      81
# Taekwondo              80
# Triathlon              18
# Name: count, dtype: int64

# %%
# plot sports with most awarded Medals 
plt.figure(figsize=(15, 5))
highest_sport = df['Sport'].value_counts().index
sb.countplot(data=df, x='Sport', order=highest_sport, palette=sb.color_palette("rocket", 28))
plt.xticks(rotation=90)
plt.title('Sports with most awarded Medals', fontsize=17, color='crimson')
plt.xlabel('Sport', fontweight='bold', color='crimson')
plt.ylabel('No. of Medals', fontweight='bold', color='crimson');
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\3609678719.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='Sport', order=highest_sport, palette=sb.color_palette("rocket", 28))

# %%
# contribution of women & men through the years
plt.figure(figsize=(15, 5))
sb.countplot(data=df, x='Year', hue='Gender', palette=['midnightblue', 'salmon'])
plt.legend(loc='center right', bbox_to_anchor=(1.15, 0.5), ncol=1)
plt.title('Contribution of women & men in Olympics through the years', fontsize=17, color='navy')
plt.xlabel('Years', fontweight='bold', color='navy')
plt.ylabel("Count of Athlete (Women/Men)", fontweight='bold', color='navy');

# %%
# contrast between women & men awarded medals in 1976 and 2008
plt.figure(figsize = [15, 5]) 

# plot Women & Men awarded Medals in 1976 Olympics
ax1 = plt.subplot(1, 2, 1)
sb.countplot(data=df.query('Year == "1976"'), x='Medal', hue='Gender', palette=['midnightblue', 'salmon'])
ax1.set_title('Women & Men awarded Medals in 1976 Olympics', fontsize=13, color='blue')
ax1.set_xlabel('Medals', fontweight='bold', color='blue')
ax1.set_ylabel('No. of Medals', fontweight='bold', color='blue')

# plot Women & Men awarded Medals in 2008 Olympics
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
sb.countplot(data=df.query('Year == "2008"'), x='Medal', hue='Gender', palette=['midnightblue', 'salmon'])
ax2.set_title('Women & Men awarded Medals in 2008 Olympics', fontsize=13, color='blue')
ax2.set_xlabel('Medals', fontweight='bold', color='blue')
ax2.set_ylabel('No. of Medals', fontweight='bold', color='blue');

# %%
df['Country'].head(15)
# Out:
# 0      East Germany
# 1      Soviet Union
# 2     United States
# 3             Italy
# 4     United States
# 5     United States
# 6      Soviet Union
# 7     United States
# 8             Italy
# 9      Soviet Union
# 10           Sweden
# 11    United States
# 12    United States
# 13    United States
# 14     East Germany
# Name: Country, dtype: object

# %%
India = df[df['Country'] == 'India']

# %%
India
# Out:
#           City  Year          Sport       Discipline  \
# 2288    Moscow  1980         Hockey           Hockey
# 2289    Moscow  1980         Hockey           Hockey
# 2294    Moscow  1980         Hockey           Hockey
# 2302    Moscow  1980         Hockey           Hockey
# 2303    Moscow  1980         Hockey           Hockey
# 2313    Moscow  1980         Hockey           Hockey
# 2320    Moscow  1980         Hockey           Hockey
# 2339    Moscow  1980         Hockey           Hockey
# 2341    Moscow  1980         Hockey           Hockey
# 2347    Moscow  1980         Hockey           Hockey
# 2348    Moscow  1980         Hockey           Hockey
# 2350    Moscow  1980         Hockey           Hockey
# 2370    Moscow  1980         Hockey           Hockey
# 2375    Moscow  1980         Hockey           Hockey
# 2377    Moscow  1980         Hockey           Hockey
# 2378    Moscow  1980         Hockey           Hockey
# 9191   Atlanta  1996         Tennis           Tennis
# 11324   Sydney  2000  Weightlifting    Weightlifting
# 13051   Athens  2004       Shooting         Shooting
# 14125  Beijing  2008         Boxing           Boxing
# 15073  Beijing  2008       Shooting         Shooting
# 15389  Beijing  2008      Wrestling  Wrestling Free.
#
#                            Event                   Athlete Gender  \
# 2288                      hockey              SINGH, Singh    Men
# 2289                      hockey         FERNANDES, Mervyn    Men
# 2294                      hockey            GURMAIL, Singh    Men
# 2302                      hockey        BASKARAN, Baskaran    Men
# 2303                      hockey              ZAFAR, Zafar    Men
# 2313                      hockey          MOHAMMAD, Shahid    Men
# 2320                      hockey              SINGH, Singh    Men
# 2339                      hockey  KAUSHIK, Maharaj Krishon    Men
# 2341                      hockey           SURINDER, Singh    Men
# 2347                      hockey          KUMAR, Charanjit    Men
# 2348                      hockey       SYLVANUS, Dung Dung    Men
# 2350                      hockey          DEAVINDER, Singh    Men
# 2370                      hockey       AMARJIT RANA, Singh    Men
# 2375                      hockey          ALLAN, Schofield    Men
# 2377                      hockey          CHETTRI, Chettri    Men
# 2378                      hockey        MANEYPANDA, Somaya    Men
# 9191                     singles             PAES, Leander    Men
# 11324                       69kg        MALLESWARI, Karnam  Women
# 13051  double trap (150 targets)  RATHORE, Rajyavardhan S.    Men
# 14125                 69 - 75 kg           KUMAR, Vijender    Men
# 15073   10m air rifle (60 shots)           BINDRA, Abhinav    Men
# 15389                  60 - 66kg             KUMAR, Sushil    Men
#
#       Country_Code Country Event_gender   Medal  Count
# 2288           IND   India            M    Gold      1
# 2289           IND   India            M    Gold      1
# 2294           IND   India            M    Gold      1
# 2302           IND   India            M    Gold      1
# 2303           IND   India            M    Gold      1
# 2313           IND   India            M    Gold      1
# 2320           IND   India            M    Gold      1
# 2339           IND   India            M    Gold      1
# 2341           IND   India            M    Gold      1
# 2347           IND   India            M    Gold      1
# 2348           IND   India            M    Gold      1
# 2350           IND   India            M    Gold      1
# 2370           IND   India            M    Gold      1
# 2375           IND   India            M    Gold      1
# 2377           IND   India            M    Gold      1
# 2378           IND   India            M    Gold      1
# 9191           IND   India            M  Bronze      1
# 11324          IND   India            W  Bronze      1
# 13051          IND   India            M  Silver      1
# 14125          IND   India            M  Bronze      1
# 15073          IND   India            M    Gold      1
# 15389          IND   India            M  Bronze      1

# %%
India['Gender'].value_counts()
# Out:
# Gender
# Men      21
# Women     1
# Name: count, dtype: int64

# %%
# plot contribution of athletes from India
plt.figure(figsize=(9, 3))
sb.countplot(data=India,  x='Gender', palette=['midnightblue', 'salmon'])
plt.legend(labels=['Men', 'Women'])
plt.title('Contribution of Indian Atheles in Olympics', fontsize=17, color='navy')
plt.xlabel('Gender', fontweight='bold', color='navy')
plt.ylabel("Count of Athlete (Women/Men)", fontweight='bold', color='navy');
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\1029079247.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=India,  x='Gender', palette=['midnightblue', 'salmon'])

# %%
# plot Medals awrded to Indian Athletes through years
plt.figure(figsize=(9, 3))
sb.countplot(data=India, x='Year', hue='Medal', palette=sb.color_palette("YlOrBr", 3))
plt.legend(loc='upper right')

plt.title('Medals awarded to Indian Athletes through years', fontsize=17, color='brown')
plt.xlabel('Years', fontweight='bold', color='brown')
plt.ylabel('No. of Medals', fontweight='bold', color='brown');

# %%
# plot the awarded sports
India.groupby('Sport')['Medal'].count().sort_values(ascending=False).plot(kind='bar', figsize=(9, 3), 
                                            color=['black', 'grey', 'lightgray', 'lightgray'])
plt.title('Awarded Sports in India', fontsize=17, color='purple')
plt.xlabel('Sport', fontweight='bold', color='purple')
plt.ylabel('No. of Medals', fontweight='bold', color='purple');

# %%
# plot awarded Indian athlete
sb.countplot(data=India, y='Athlete', hue='Medal', palette=sb.color_palette("YlOrBr", 3))
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
# plot Indian athletes and corresponding sport
India.groupby(['Sport'])['Athlete'].value_counts(4).plot(kind='bar', figsize=(9, 3), 
                            color=['tan', 'tan', 'tan', 'tan', 'silver', 'silver', 'goldenrod'])
plt.title('Indian awarded Atletes', fontsize=17, color='brown')
plt.tick_params(axis='x', labelsize=13)
plt.xlabel('Athlete name & Medal & Sport', fontweight='bold', fontsize=15, color='brown')
plt.ylabel('No. of awrded medals', color='brown');

# %%
# create df for tennis sport
Wrestling = df[df['Sport'] == 'Wrestling']

# %%
 Wrestling
# Out:
#            City  Year      Sport       Discipline  \
# 1362   Montreal  1976  Wrestling  Wrestling Free.
# 1363   Montreal  1976  Wrestling  Wrestling Free.
# 1364   Montreal  1976  Wrestling  Wrestling Free.
# 1365   Montreal  1976  Wrestling  Wrestling Free.
# 1366   Montreal  1976  Wrestling  Wrestling Free.
# ...         ...   ...        ...              ...
# 15428   Beijing  2008  Wrestling  Wrestling Gre-R
# 15429   Beijing  2008  Wrestling  Wrestling Gre-R
# 15430   Beijing  2008  Wrestling  Wrestling Gre-R
# 15431   Beijing  2008  Wrestling  Wrestling Gre-R
# 15432   Beijing  2008  Wrestling  Wrestling Gre-R
#
#                              Event               Athlete Gender Country_Code  \
# 1362     57 - 62kg (featherweight)      OIDOV, Zevegying    Men          MGL
# 1363       62 - 68kg (lightweight)    SUGAWARA, Yasaburo    Men          JPN
# 1364      74 - 82kg (middleweight)  PETERSON, John Allan    Men          USA
# 1365   + 100kg (super heavyweight)         BALLA, Jozsef    Men          HUN
# 1366      74 - 82kg (middleweight)          SEGER, Adolf    Men          FRG
# ...                            ...                   ...    ...          ...
# 15428                    66 - 74kg    GUENOT, Christophe    Men          FRA
# 15429                    66 - 74kg   KVIRKELIA, Manuchar    Men          GEO
# 15430                    55 - 60kg      RAHIMOV, Vitaliy    Men          AZE
# 15431                    60 - 66kg        GUENOT, Steeve    Men          FRA
# 15432                   96 - 120kg         LOPEZ, Mijain    Men          CUB
#
#              Country Event_gender   Medal  Count
# 1362        Mongolia            M  Silver      1
# 1363           Japan            M  Bronze      1
# 1364   United States            M    Gold      1
# 1365         Hungary            M  Silver      1
# 1366    West Germany            M  Bronze      1
# ...              ...          ...     ...    ...
# 15428         France            M  Bronze      1
# 15429        Georgia            M    Gold      1
# 15430     Azerbaijan            M  Silver      1
# 15431         France            M    Gold      1
# 15432           Cuba            M    Gold      1
#
# [533 rows x 12 columns]

# %%
df['Sport']
# Out:
# 0         Aquatics
# 1         Aquatics
# 2         Aquatics
# 3         Aquatics
# 4         Aquatics
#            ...
# 15428    Wrestling
# 15429    Wrestling
# 15430    Wrestling
# 15431    Wrestling
# 15432    Wrestling
# Name: Sport, Length: 15316, dtype: object

# %%
# plot medals awarded in tennis through time
plt.figure(figsize=(9, 3));
sb.countplot(data=Wrestling, x='Year', hue='Medal', palette=sb.color_palette("YlOrBr", 3))
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.title('Medals awarded in Wrestling Sport through years', fontsize=17, color='brown')
plt.xlabel('Years', fontweight='bold', color='brown')
plt.ylabel('No. of Medals', fontweight='bold', color='brown');

# %%
# plot Contribution of Athlete in Wrestling
plt.figure(figsize=(10, 4));
sb.countplot(data=Wrestling, x='Year', hue='Gender', palette=['midnightblue', 'salmon'])
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.title('Contribution of Athlete in Wrestling Sport through years', fontsize=17, color='navy')
plt.xlabel('Years', fontweight='bold', color='navy')
plt.ylabel("Count of Athlete (Women/Men)", fontweight='bold', color='navy');

# %%
# plot medals awarded to athletes in Wrestling
plt.figure(figsize=(9, 4));
sb.countplot(data=Wrestling, x='Medal', hue='Gender', palette=['midnightblue', 'salmon'])
# Out:
# <Axes: xlabel='Medal', ylabel='count'>

# %%
# plot top countries in Wrestling
Wrestling['Country'].value_counts().plot.bar(figsize=(12, 5))
# Out:
# <Axes: xlabel='Country'>

# %%
# plot top (women) countries in Wrestling
Wrestling.query('Gender == "Women"')['Country'].value_counts().plot.bar(figsize=(12, 5), cmap=plt.get_cmap('Spectral'))
plt.title('Top awarded Countries in Tennis Sport for Women', fontsize=17, color='crimson')
plt.tick_params(axis='x', labelsize=13)
plt.xlabel('Country', fontweight='bold', color='crimson')
plt.ylabel('No. of Medals', fontweight='bold', color='crimson');

# %%
Hockey = df[df['Sport'] == 'Hockey']

# %%
Hockey
# Out:
#            City  Year   Sport Discipline   Event                 Athlete  \
# 960    Montreal  1976  Hockey     Hockey  hockey          PARKIN, Arthur
# 961    Montreal  1976  Hockey     Hockey  hockey          WALSH, Terence
# 962    Montreal  1976  Hockey     Hockey  hockey       MARSHALL, Stephen
# 963    Montreal  1976  Hockey     Hockey  hockey  MAISTER, Selwyn Gerald
# 964    Montreal  1976  Hockey     Hockey  hockey             WILSON, Les
# ...         ...   ...     ...        ...     ...                     ...
# 14798   Beijing  2008  Hockey     Hockey  hockey             BROWN, Kiel
# 14799   Beijing  2008  Hockey     Hockey  hockey        LAMBERT, Stephen
# 14800   Beijing  2008  Hockey     Hockey  hockey       KANEVSKY, Giselle
# 14801   Beijing  2008  Hockey     Hockey  hockey       AICEGA, Magdalena
# 14802   Beijing  2008  Hockey     Hockey  hockey       AGLIOTTI, Marilyn
#
#       Gender Country_Code      Country Event_gender   Medal  Count
# 960      Men          NZL  New Zealand            M    Gold      1
# 961      Men          AUS    Australia            M  Silver      1
# 962      Men          AUS    Australia            M  Silver      1
# 963      Men          NZL  New Zealand            M    Gold      1
# 964      Men          NZL  New Zealand            M    Gold      1
# ...      ...          ...          ...          ...     ...    ...
# 14798    Men          AUS    Australia            M  Bronze      1
# 14799    Men          AUS    Australia            M  Bronze      1
# 14800  Women          ARG    Argentina            W  Bronze      1
# 14801  Women          ARG    Argentina            W  Bronze      1
# 14802  Women          NED  Netherlands            W    Gold      1
#
# [817 rows x 12 columns]

# %%
# plot medals awarded in Hockey through time
plt.figure(figsize=(9, 4))
sb.countplot(data=Hockey, x='Year', hue='Medal', palette=sb.color_palette("YlOrBr", 3))
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.title('Medals awarded in Hockey Sport through years', fontsize=17, color='brown')
plt.xlabel('Years', fontweight='bold', color='brown')
plt.ylabel('No. of Medals', fontweight='bold', color='brown');

# %%
Hockey.groupby(['Year', 'Gender'])['Medal'].size()
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\168057170.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Hockey.groupby(['Year', 'Gender'])['Medal'].size()
# Year  Gender
# 1976  Men       48
#       Women      0
# 1980  Men       48
#       Women     48
# 1984  Men       48
#       Women     48
# 1988  Men       48
#       Women     48
# 1992  Men       48
#       Women     48
# 1996  Men       48
#       Women     48
# 2000  Men       48
#       Women     48
# 2004  Men       48
#       Women     47
# 2008  Men       50
#       Women     48
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(9, 5))
sb.countplot(data=Hockey, x='Year', hue='Gender', palette=['midnightblue', 'salmon'])
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.title('Contribution of Athlete in Hockey Sport through years', fontsize=17, color='navy')
plt.xlabel('Years', fontweight='bold', color='navy')
plt.ylabel("Count of Athlete (Women/Men)", fontweight='bold', color='navy');

# %%
plt.figure(figsize=(9, 5))
sb.countplot(data=Hockey, x='Medal', hue='Gender', palette=['midnightblue', 'salmon'])
# Out:
# <Axes: xlabel='Medal', ylabel='count'>

# %%
Hockey['Country'].value_counts().plot.bar(figsize=(15, 5))
plt.show()

# %%
Hockey.query('Gender == "Women"')['Country'].value_counts().plot.bar(figsize=(15, 5), color='green')
plt.title('Top awarded Countries in Hockey Sport for Women', fontsize=17)
plt.tick_params(axis='x', labelsize=15)
plt.xlabel('Country', fontweight='bold')
plt.ylabel('No. of Medals', fontweight='bold');

# %%
df['Country'].unique()
# Out:
# array(['East Germany', 'Soviet Union', 'United States', 'Italy', 'Sweden',
#        'Australia', 'Canada', 'West Germany', 'Netherlands',
#        'United Kingdom', 'Hungary', 'Japan', 'Cuba', 'Poland', 'Bulgaria',
#        'New Zealand', 'Belgium', 'Mexico', 'Jamaica', 'Finland',
#        'Romania', 'Portugal', 'France', 'Brazil', 'Czechoslovakia',
#        'Trinidad and Tobago', 'Yugoslavia', 'Venezuela', 'Puerto Rico*',
#        'Korea, North', 'Bermuda*', 'Thailand', 'Spain', 'Denmark',
#        'Switzerland', 'Pakistan', 'Korea, South', 'Norway', 'Austria',
#        'Iran', 'Mongolia', 'Ethiopia', 'Tanzania', 'Guyana', 'Uganda',
#        'Ireland', 'India', 'Zimbabwe', 'Greece', 'Lebanon', 'China',
#        'Nigeria', 'Kenya', 'Morocco', "Cote d'Ivoire", 'Algeria',
#        'Turkey', 'Cameroon', 'Zambia', 'Dominican Republic', 'Iceland',
#        'Egypt', 'Colombia', 'Peru', 'Taiwan', 'Syria', 'Costa Rica',
#        'Suriname', 'Indonesia', 'Djibouti', 'Senegal', 'Philippines',
#        'Netherlands Antilles*', 'Virgin Islands*', 'Chile', 'Argentina',
#        'Unified team', 'Germany', 'Bahamas', 'South Africa', 'Namibia',
#        'Qatar', 'Lithuania', 'Malaysia', 'Croatia', 'Latvia', 'Estonia',
#        'Ghana', 'Israel', 'Slovenia',
#        'Independent Olympic Participants (1992)', 'Russia', 'Ukraine',
#        'Belarus', 'Burundi', 'Ecuador', 'Mozambique', 'Czech Republic',
#        'Tunisia', 'Kazakhstan', 'Tonga', 'Uzbekistan', 'Slovakia',
#        'Moldova', 'Georgia', 'Hong Kong*', 'Armenia', 'Azerbaijan',
#        'Saudi Arabia', 'Barbados', 'Sri Lanka', 'Uruguay', 'Kyrgyzstan',
#        'Kuwait', 'Vietnam', 'Macedonia', 'Serbia', 'Eritrea', 'Paraguay',
#        'United Arab Emirates', 'Panama', 'Sudan', 'Mauritius', 'Togo',
#        'Tajikistan', 'Singapore', 'Afghanistan'], dtype=object)

# %%
Asia = ['India', 'Russia', 'Japan', 'Iraq', 'Korea, North', 'Thailand', 'Kuwait', 'Pakistan', 'Oman', 'Saudi Arabia',
'Korea, South', 'Qatar', 'China', 'Indonesia', 'United Arab Emirates', 'Yemen', 'Malaysia', 'Sri Lanka', 'Iran', 'Soviet Union']

df1 = df[df['Country'].isin(Asia)]
df2 = df[~df['Country'].isin(Asia)]
df3 = df.loc[df['Country'] == 'United States']

# %%
plt.figure(figsize=(12, 5))
sb.regplot(data=df1, x= 'Year', y='Country', fit_reg= False, scatter_kws={'alpha':1/2, 'color':'orangered'})
sb.regplot(data=df2, x= 'Year', y='Country', fit_reg= False, scatter_kws={'alpha':1/2, 'color':'mediumblue'})
sb.regplot(data=df3, x= 'Year', y='Country', fit_reg= False, scatter_kws={'color':'pink'})

plt.yticks('')
sb.set(style="whitegrid")
plt.legend(labels=['Asia', 'Outside Asia', 'USA'], loc='center right', bbox_to_anchor=(1.35, 0.5));
plt.title('Contribution of Asia Athletes in Olympics vs. the rest of world through years', fontsize=17, color='navy')
plt.xlabel('Years', fontweight='bold', color='navy')
plt.ylabel('Countries', fontweight='bold', color='navy');

# %%
Gender_Medal = pd.DataFrame(df.groupby(['Year','Medal', 'Gender']).size()).reset_index()
Gender_Medal.columns = ['Year', 'Medal', 'Gender', 'Count']
Gender_Medal.head(3)
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\419810284.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Gender_Medal = pd.DataFrame(df.groupby(['Year','Medal', 'Gender']).size()).reset_index()
#    Year   Medal Gender  Count
# 0  1976  Bronze    Men    321
# 1  1976  Bronze  Women    126
# 2  1976  Silver    Men    301

# %%
Gender_Medal = pd.DataFrame(df.groupby(['Year', 'Gender', 'Medal']).size()).reset_index()
Gender_Medal.columns = ['Year', 'Gender', 'Medal', 'Count']
Gender_Medal.head(3)
# Out:
# C:\Users\Ramdev\AppData\Local\Temp\ipykernel_24232\2473363099.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Gender_Medal = pd.DataFrame(df.groupby(['Year', 'Gender', 'Medal']).size()).reset_index()
#    Year Gender   Medal  Count
# 0  1976    Men  Bronze    321
# 1  1976    Men  Silver    301
# 2  1976    Men    Gold    302

# %%
# facet the distribution of medal(bronze, silver, gold) awrded to athlete(women, men)
g = sb.FacetGrid(data=Gender_Medal, col='Medal', hue='Gender', palette=['midnightblue', 'salmon'], margin_titles=True, height=4)
g.map(sb.kdeplot, 'Count', shade=True)

g.add_legend()
g.fig.suptitle('Distribution of total Olympics awarded Medals', fontsize=17, color='darkblue')
g.fig.subplots_adjust(top=0.8)
g.set_titles(color = 'brown', fontweight='bold')

g.axes[0,0].set_ylabel('Dist.', fontweight='bold', color='brown')

g.axes[0,0].set_xlabel('Count of Bronze Medals Awarded', fontweight='bold', color='brown')
g.axes[0,1].set_xlabel('Count of Silver Medals Awarded', fontweight='bold', color='brown')
g.axes[0,2].set_xlabel('Count of Gold Medals Awarded', fontweight='bold', color='brown')
sb.set_style("whitegrid");
# Out:
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramdev\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# facet the correlation of medal(bronze, silver, gold) awrded to athlete(women, men) through time
g = sb.FacetGrid(data=Gender_Medal, col='Medal', hue='Gender', palette=['midnightblue', 'salmon'], margin_titles=True, height=4)
g.map_dataframe(plt.scatter, x='Year', y='Count')


g.add_legend()
g.fig.suptitle('Correlation of total Olympics awarded Medals to Women/Men', fontsize=17, color='indianred')
g.fig.subplots_adjust(top=0.8)
g.set_titles(color = 'crimson', fontweight='bold')

g.axes[0,0].set_ylabel('Count of Medals', fontweight='bold', color='crimson')


g.axes[0,0].set_xlabel('Year', fontweight='bold', color='crimson')
g.axes[0,1].set_xlabel('Year', fontweight='bold', color='crimson')
g.axes[0,2].set_xlabel('Year', fontweight='bold', color='crimson')

sb.set_style("whitegrid");

# %%
df.head(10)
# Out:
#        City  Year     Sport Discipline           Event  \
# 0  Montreal  1976  Aquatics     Diving  3m springboard
# 1  Montreal  1976  Aquatics     Diving  3m springboard
# 2  Montreal  1976  Aquatics     Diving  3m springboard
# 3  Montreal  1976  Aquatics     Diving  3m springboard
# 4  Montreal  1976  Aquatics     Diving    10m platform
# 5  Montreal  1976  Aquatics     Diving    10m platform
# 6  Montreal  1976  Aquatics     Diving    10m platform
# 7  Montreal  1976  Aquatics     Diving  3m springboard
# 8  Montreal  1976  Aquatics     Diving    10m platform
# 9  Montreal  1976  Aquatics     Diving    10m platform
#
#                      Athlete Gender Country_Code        Country Event_gender  \
# 0            KÖHLER, Christa  Women          GDR   East Germany            W
# 1        KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2       BOGGS, Philip George    Men          USA  United States            M
# 3   CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4     WILSON, Deborah Keplar  Women          USA  United States            W
# 5          LOUGANIS, Gregory    Men          USA  United States            M
# 6     VAYTSEKHOVSKAYA, Elena  Women          URS   Soviet Union            W
# 7  POTTER-MCINGVALE, Cynthia  Women          USA  United States            W
# 8             DIBIASI, Klaus    Men          ITA          Italy            M
# 9          ALEINIK, Vladimir    Men          URS   Soviet Union            M
#
#     Medal  Count
# 0  Silver      1
# 1  Bronze      1
# 2    Gold      1
# 3  Silver      1
# 4  Bronze      1
# 5  Silver      1
# 6    Gold      1
# 7  Bronze      1
# 8    Gold      1
# 9  Bronze      1

# %%
Hockey.head(10)
# Out:
#          City  Year   Sport Discipline   Event                 Athlete Gender  \
# 960  Montreal  1976  Hockey     Hockey  hockey          PARKIN, Arthur    Men
# 961  Montreal  1976  Hockey     Hockey  hockey          WALSH, Terence    Men
# 962  Montreal  1976  Hockey     Hockey  hockey       MARSHALL, Stephen    Men
# 963  Montreal  1976  Hockey     Hockey  hockey  MAISTER, Selwyn Gerald    Men
# 964  Montreal  1976  Hockey     Hockey  hockey             WILSON, Les    Men
# 965  Montreal  1976  Hockey     Hockey  hockey          ACKERLEY, Paul    Men
# 966  Montreal  1976  Hockey     Hockey  hockey            REID, Graham    Men
# 967  Montreal  1976  Hockey     Hockey  hockey         BORREN, Thurman    Men
# 968  Montreal  1976  Hockey     Hockey  hockey    CHAUDHRY, Arshad Ali    Men
# 969  Montreal  1976  Hockey     Hockey  hockey  MC INTYRE, Alan Lionel    Men
#
#     Country_Code      Country Event_gender   Medal  Count
# 960          NZL  New Zealand            M    Gold      1
# 961          AUS    Australia            M  Silver      1
# 962          AUS    Australia            M  Silver      1
# 963          NZL  New Zealand            M    Gold      1
# 964          NZL  New Zealand            M    Gold      1
# 965          NZL  New Zealand            M    Gold      1
# 966          AUS    Australia            M  Silver      1
# 967          NZL  New Zealand            M    Gold      1
# 968          PAK     Pakistan            M  Bronze      1
# 969          NZL  New Zealand            M    Gold      1
